# %% [markdown]
# <a href="https://colab.research.google.com/github/AyushGupte-22/Machine_Learning_Lab_120/blob/main/ML_LAB_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import pandas as pd
 from sklearn.neighbors import KNeighborsClassifier
 from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
 import matplotlib.pyplot as plt

# %%
 X = [
 [150, 50],
 [160, 60],
 [170, 65],
 [180, 80],
 [190, 85],
 [200, 90]
 ]
 y = [0,0,0,1,1,1]
 knn = KNeighborsClassifier(n_neighbors=3)
 knn.fit(X,y)
# Out:
# KNeighborsClassifier(n_neighbors=3)

# %%
 X_test = [
 [155,55],
 [185,82]
 ]
 y_test = [0,1]
 y_pred = knn.predict(X_test)
 print("Predition:", y_pred)
# Out:
# Predition: [0 1]

# %%
 cm = confusion_matrix(y_test, y_pred)
 disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=["Class A","class B"])
 disp.plot()
 plt.show()
